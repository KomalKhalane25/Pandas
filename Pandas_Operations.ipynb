# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalKhalane25/Pandas/blob/main/Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {'Company':['A','A','B','B','C','C'],
        'Person':['komal','ram','Rahul','Shiv','Rohan','Rani'],
        'Sales':[520,404,889,506,632,756]}
df = pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0       A  komal    520
# 1       A    ram    404
# 2       B  Rahul    889
# 3       B   Shiv    506
# 4       C  Rohan    632
# 5       C   Rani    756

# %%
#head and tail
df.head()
# Out:
#   Company Person  Sales
# 0       A  komal    520
# 1       A    ram    404
# 2       B  Rahul    889
# 3       B   Shiv    506
# 4       C  Rohan    632

# %%
df.tail()
# Out:
#   Company Person  Sales
# 1       A    ram    404
# 2       B  Rahul    889
# 3       B   Shiv    506
# 4       C  Rohan    632
# 5       C   Rani    756

# %%
df.head(2)
# Out:
#   Company Person  Sales
# 0       A  komal    520
# 1       A    ram    404

# %%
df.tail(2)
# Out:
#   Company Person  Sales
# 4       C  Rohan    632
# 5       C   Rani    756

# %%
df= pd.DataFrame({'col1':[1,2,3,4,5],
                  'col2':[42,56,56,35,78],
                  'cole3':['abc','efg','onp','dfg','dgd']})

# %%
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
#unique() and nunique()
df['col2'].unique()
# Out:
# array([42, 56, 35, 78])

# %%
df['col2'].nunique()
# Out:
# 4

# %%
#value counts() is very imortan function used widely.

df['col2'].value_counts()
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
#conditions
df['col2'] == 56
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: col2, dtype: bool

# %%
#multiple conditions using &,|

10==10 and 14==11
# Out:
# False

# %%
print(df)
print('********')
(df['col1']>1) & (df['col2']==56)
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd
# ********
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
print(df)
print('********')
(df['col1']>2) | (df['col2']==56)
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd
# ********
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
def times2(x):
  return 2*x

# %%
times2(10)
# Out:
# 20

# %%
times2(3)
# Out:
# 6

# %%
df['col2'].apply(times2)
# Out:
# 0     84
# 1    112
# 2    112
# 3     70
# 4    156
# Name: col2, dtype: int64

# %%
df['cole3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: cole3, dtype: int64

# %%
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
df.drop(3)
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 4     5    78   dgd

# %%
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
df.drop('col2',axis=1)
# Out:
#    col1 cole3
# 0     1   abc
# 1     2   efg
# 2     3   onp
# 3     4   dfg
# 4     5   dgd

# %%
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
del df['cole3']

# %%
df
# Out:
#    col1  col2
# 0     1    42
# 1     2    56
# 2     3    56
# 3     4    35
# 4     5    78

# %%
#colunms and Index
df.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#isnull and sort_values()

df= pd.DataFrame({'col1':[1,2,3,4,5],
                  'col2':[42,56,56,35,78],
                  'cole3':['abc','efg','onp','dfg','dgd']})
df
# Out:
#    col1  col2 cole3
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 3     4    35   dfg
# 4     5    78   dgd

# %%
df.sort_values('col2') #by default assending
# Out:
#    col1  col2 cole3
# 3     4    35   dfg
# 0     1    42   abc
# 1     2    56   efg
# 2     3    56   onp
# 4     5    78   dgd

# %%
df.sort_values('col2',ascending=False)
# Out:
#    col1  col2 cole3
# 4     5    78   dgd
# 2     3    56   onp
# 1     2    56   efg
# 0     1    42   abc
# 3     4    35   dfg

# %%
#isnull()
df = pd.DataFrame({'col1':[1,2,3,4,5],
                  'col2':[42,56,np.nan,35,78],
                  'cole3':['abc','efg','onp','dfg','dgd']})
df
# Out:
#    col1  col2 cole3
# 0     1  42.0   abc
# 1     2  56.0   efg
# 2     3   NaN   onp
# 3     4  35.0   dfg
# 4     5  78.0   dgd

# %%
df.isnull()
# Out:
#     col1   col2  cole3
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False  False
# 4  False  False  False
