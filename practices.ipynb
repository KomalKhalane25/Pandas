# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalKhalane25/Pandas/blob/main/practices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/student_depression_dataset.csv')

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#             Sleep Duration Dietary Habits      Degree  \
# 27896          '5-6 hours'      Unhealthy  'Class 12'
# ...

# %%
df.tail(2)
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 27899  140690  Female  18.0  Ludhiana    Student                5.0
# 27900  140699    Male  27.0     Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#             Sleep Duration Dietary Habits      Degree  \
# 27899  'Less than 5 hours'        Healthy  'Class 12'
# 27900  'Less than 5 hours'        Healthy         BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 27899              5.0                               No           1
# ...

# %%
df.info() #give me meta data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df.describe() #escriptive statistics
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df[::-5]
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 27900  140699    Male  27.0          Patna    Student                4.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27890  140635    Male  28.0       Ludhiana    Student                3.0
# 27885  140597  Female  19.0         Mumbai    Student                2.0
# 27880  140558    Male  24.0         Nagpur    Student                3.0
# ...       ...     ...   ...            ...        ...                ...
# 20        161    Male  29.0        Kolkata    Student                3.0
# 15        106    Male  29.0       Srinagar    Student                3.0
# 10         83    Male  24.0         Nagpur    Student                3.0
# 5          33    Male  29.0           Pune    Student                2.0
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df['Gender']
# Out:
# 0          Male
# 1        Female
# 2          Male
# 3        Female
# 4        Female
#           ...
# 27896    Female
# 27897      Male
# 27898      Male
# 27899    Female
# 27900      Male
# Name: Gender, Length: 27901, dtype: object

# %%
df[['Gender', 'Age' , 'City','CGPA']]
# Out:
#        Gender   Age           City  CGPA
# 0        Male  33.0  Visakhapatnam  8.97
# 1      Female  24.0      Bangalore  5.90
# 2        Male  31.0       Srinagar  7.03
# 3      Female  28.0       Varanasi  5.59
# 4      Female  25.0         Jaipur  8.13
# ...       ...   ...            ...   ...
# 27896  Female  27.0          Surat  5.75
# 27897    Male  27.0       Ludhiana  9.40
# 27898    Male  31.0      Faridabad  6.61
# 27899  Female  18.0       Ludhiana  6.88
# 27900    Male  27.0          Patna  9.24
#
# [27901 rows x 4 columns]

# %%
df[5:15][['Gender', 'Age' , 'City','CGPA']]
# Out:
#     Gender   Age      City  CGPA
# 5     Male  29.0      Pune  5.70
# 6     Male  30.0     Thane  9.54
# 7   Female  30.0   Chennai  8.04
# 8     Male  28.0    Nagpur  9.79
# 9     Male  31.0    Nashik  8.38
# 10    Male  24.0    Nagpur  6.10
# 11    Male  33.0  Vadodara  7.03
# 12    Male  27.0    Kalyan  7.04
# 13  Female  19.0    Rajkot  8.52
# 14  Female  19.0    Kalyan  5.64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=8,4

# %%
vis1 = sns.distplot(df.Age)
# Out:
# <ipython-input-45-b7b280eb019c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1 = sns.distplot(df.Age)

# %%
 vis2 = sns.displot(df.Age)

# %%
 vis3 = sns.boxplot(data=df, x='Dietary Habits', y='Sleep Duration')

# %%
vis4 = sns.lmplot(data=df, x='CGPA', y='Age')

# %%
vis4 = sns.lmplot(data=df, x='CGPA', y='Age',fit_reg=False)

# %%
vis4 = sns.lmplot(data=df, x='CGPA', y='Age',fit_reg=False,hue='Gender')

# %%
vis4 = sns.lmplot(data=df, x='CGPA', y='Age',fit_reg=False, hue='Gender',height=10)
